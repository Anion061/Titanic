# %%
import pandas as pd

# %%
df=pd.read_csv("D:/Datasets/TitanicTrain.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x="Sex",y='Age',data=df,whis=[5,95])
plt.show()

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin',axis="columns",inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.drop("Embarked",axis="columns",inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %%
y=df["Survived"]

# %%
X=df.drop(["PassengerId","Survived","Name","Ticket"],axis="columns")

# %%
X
# Out:
#      Pclass     Sex        Age  SibSp  Parch     Fare
# 0         3    male  22.000000      1      0   7.2500
# 1         1  female  38.000000      1      0  71.2833
# 2         3  female  26.000000      0      0   7.9250
# 3         1  female  35.000000      1      0  53.1000
# 4         3    male  35.000000      0      0   8.0500
# ..      ...     ...        ...    ...    ...      ...
# 886       2    male  27.000000      0      0  13.0000
# 887       1  female  19.000000      0      0  30.0000
# 888       3  female  29.699118      1      2  23.4500
# 889       1    male  26.000000      0      0  30.0000
# 890       3    male  32.000000      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
X=pd.get_dummies(X,columns=["Sex"])

# %%
X
# Out:
#      Pclass        Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 0         3  22.000000      1      0   7.2500           0         1
# 1         1  38.000000      1      0  71.2833           1         0
# 2         3  26.000000      0      0   7.9250           1         0
# 3         1  35.000000      1      0  53.1000           1         0
# 4         3  35.000000      0      0   8.0500           0         1
# ..      ...        ...    ...    ...      ...         ...       ...
# 886       2  27.000000      0      0  13.0000           0         1
# 887       1  19.000000      0      0  30.0000           1         0
# 888       3  29.699118      1      2  23.4500           1         0
# 889       1  26.000000      0      0  30.0000           0         1
# 890       3  32.000000      0      0   7.7500           0         1
#
# [891 rows x 7 columns]

# %%
from keras.utils import to_categorical

# %%
y=to_categorical(y)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
y.shape
# Out:
# (891, 2)

# %% [markdown]
# # Step 1: Specify the architecture

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(128,activation="relu",input_shape=(7,)))
model.add(Dense(64,activation="relu"))
model.add(Dense(2,activation="softmax"))

# %% [markdown]
# # Step 2: Compile the model

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %% [markdown]
# # Step 3: Fit the model

# %%
model.fit(X,y,epochs=15)
# Out:
# Epoch 1/15
# 28/28 [==============================] - 0s 988us/step - loss: 0.4286 - accuracy: 0.8148
# Epoch 2/15
# 28/28 [==============================] - 0s 996us/step - loss: 0.4019 - accuracy: 0.8159
# Epoch 3/15
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4020 - accuracy: 0.8204
# Epoch 4/15
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8283
# Epoch 5/15
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8294
# Epoch 6/15
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8305
# Epoch 7/15
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8373
# Epoch 8/15
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3873 - accuracy: 0.8294
# Epoch 9/15
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3874 - accuracy: 0.8294
# Epoch 10/15
# ...

# %% [markdown]
# # Step 4: Predict

# %%
X
# Out:
#      Pclass        Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 0         3  22.000000      1      0   7.2500           0         1
# 1         1  38.000000      1      0  71.2833           1         0
# 2         3  26.000000      0      0   7.9250           1         0
# 3         1  35.000000      1      0  53.1000           1         0
# 4         3  35.000000      0      0   8.0500           0         1
# ..      ...        ...    ...    ...      ...         ...       ...
# 886       2  27.000000      0      0  13.0000           0         1
# 887       1  19.000000      0      0  30.0000           1         0
# 888       3  29.699118      1      2  23.4500           1         0
# 889       1  26.000000      0      0  30.0000           0         1
# 890       3  32.000000      0      0   7.7500           0         1
#
# [891 rows x 7 columns]

# %%
data=pd.DataFrame({"Pclass":[1],"Age":[23],"SibSp":[2],"Parch":[2],"Fare":[70],"Sex_female":[1],"Sex_male":[0]})

# %%
data.shape
# Out:
# (1, 7)

# %%
X.shape
# Out:
# (891, 7)

# %%
model.predict(data)
# Out:
# array([[0.03589784, 0.9641021 ]], dtype=float32)
